# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/somitemp/Kuliah/Semester 8/Data Warehouse/Proyek/STG_EHP_DATASET/STG_EHP__INVN/STG_EHP__INVN_1_1.csv")
df
# Out:
#            MAT_SKU    INGTN_TS  OPEN_QTY OPEN_STF  RCVD_QTY RCVD_STF  \
# 0        A0A286718  2025-01-01    1100.0    7697I       0.0    7979P
# 1        A0A286718  2025-01-02    1099.0    7511Y       0.0    1236B
# 2        A0A286718  2025-01-03    1097.0    8187E       0.0    3084J
# 3        A0A286718  2025-01-04    1094.0    2907B       0.0    5555S
# 4        A0A286718  2025-01-05    1092.0    3540T       0.0    2325F
# ...            ...         ...       ...      ...       ...      ...
# 949995  A33S259765  2025-08-30      99.0    5452S       0.0    2860L
# 949996  A33S259765  2025-08-31      98.0    4992B       0.0    4838F
# 949997  A33S259765  2025-09-01      94.0    3189O       0.0    4071N
# 949998  A33S259765  2025-09-02      92.0    2424V       0.0    2013X
# 949999  A33S259765  2025-09-03      92.0    2625S       0.0    2906Z
#
#         ISSD_QTY ISSD_STF  CLSD_QTY CLSD_STF VRFC_STF
# 0              1    6660S    1099.0    4071N    6311W
# ...

# %%
df2 = pd.read_csv("/home/somitemp/Kuliah/Semester 8/Data Warehouse/Proyek/STG_EHP_DATASET/STG_EHP__INVN/STG_EHP__INVN_1_2.csv")
df2
# Out:
#            MAT_SKU    INGTN_TS  OPEN_QTY OPEN_STF  RCVD_QTY RCVD_STF  \
# 0       A33S259765  2025-09-04      92.0    4838B       0.0    1737I
# 1       A33S259765  2025-09-05      91.0    1390G       0.0    2218G
# 2       A33S259765  2025-09-06      88.0    5355Q       0.0    3738W
# 3       A33S259765  2025-09-07      85.0    5765H       0.0    6731L
# 4       A33S259765  2025-09-08      84.0    5061J       0.0    3795G
# ...            ...         ...       ...      ...       ...      ...
# 949995  A58L973514  2025-08-14     250.0    2161G       0.0    6537U
# 949996  A58L973514  2025-08-15     248.0    8609F       0.0    3404V
# 949997  A58L973514  2025-08-16     243.0    5326H       0.0    8371Y
# 949998  A58L973514  2025-08-17     241.0    5664E       0.0    8386F
# 949999  A58L973514  2025-08-18     241.0    6555N       0.0    7053R
#
#         ISSD_QTY ISSD_STF  CLSD_QTY CLSD_STF VRFC_STF
# 0              1    5052O      91.0    6529N    4620M
# ...

# %%
df3 = pd.read_csv("STG_EHP_DATASET/STG_EHP__INVN/STG_EHP__INVN_6_18.csv")
df3
# Out:
#            MAT_SKU    INGTN_TS  OPEN_QTY OPEN_STF  RCVD_QTY RCVD_STF  \
# 0       Z65G118492  2025-01-17    1062.0    3113I       0.0    6582I
# 1       Z65G118492  2025-01-18    1058.0    6892R       0.0    1264Q
# 2       Z65G118492  2025-01-19    1057.0    5640E       0.0    1314E
# 3       Z65G118492  2025-01-20    1055.0    7847I       0.0    2735Z
# 4       Z65G118492  2025-01-21    1051.0    8333N       0.0    2378H
# ...            ...         ...       ...      ...       ...      ...
# 949995   Z8Q455799  2025-09-17       9.0    8593M       0.0    2200U
# 949996   Z8Q455799  2025-09-18       9.0    3406Y       0.0    1307W
# 949997   Z8Q455799  2025-09-19       9.0    4751C       0.0    4084V
# 949998   Z8Q656656  2025-01-01    1150.0    6532X       0.0    8518J
# 949999   Z8Q656656  2025-01-02    1147.0    6807Y       0.0    1743Z
#
#         ISSD_QTY ISSD_STF  CLSD_QTY CLSD_STF VRFC_STF
# 0              4    4217N    1058.0    6795U    2133V
# ...

# %%
df4 = pd.read_csv("/home/somitemp/Kuliah/Semester 8/Data Warehouse/Proyek/STG_EHP_DATASET/STG_EHP__INVN/STG_EHP__INVN_6_19.csv")
df4
# Out:
#           MAT_SKU    INGTN_TS  OPEN_QTY OPEN_STF  RCVD_QTY RCVD_STF  ISSD_QTY  \
# 0       Z8Q656656  2025-01-03    1144.0    8462F       0.0    1504Y         4
# 1       Z8Q656656  2025-01-04    1140.0    6358U       0.0    6503F         4
# 2       Z8Q656656  2025-01-05    1136.0    5547E       0.0    8193U         3
# 3       Z8Q656656  2025-01-06    1133.0    5812C       0.0    2987P         4
# 4       Z8Q656656  2025-01-07    1129.0    5117Y       0.0    2218E         2
# ...           ...         ...       ...      ...       ...      ...       ...
# 397447  Z9Z900387  2025-09-15     229.0    7499W       0.0    7514X         1
# 397448  Z9Z900387  2025-09-16     228.0    2409H       0.0    2682P         4
# 397449  Z9Z900387  2025-09-17     224.0    3157T       0.0    4268L         0
# 397450  Z9Z900387  2025-09-18     224.0    7160A       0.0    8762Z         2
# 397451  Z9Z900387  2025-09-19     222.0    8128R       0.0    3252G         4
#
# ...
